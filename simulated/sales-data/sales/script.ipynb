# %%
import numpy as np
import pandas as pd

# %%
class Sale:
    def __init__(
            self,
            date,
            clientName,
            clientType,
            productId,
            productName,
            productCategory,
            productPrice,
            saleAmount,
            saleDiscount,
    ):
        self.date = date
        self.clientName = clientName
        self.clientType = clientType
        self.productId = productId
        self.productName = productName
        self.productCategory = productCategory
        self.productPrice = productPrice
        self.saleAmount = saleAmount
        self.saleDiscount = saleDiscount

    def to_dict(self):
        return {
            "date": self.date,
            "clientName": self.clientName,
            "clientType": self.clientType,
            "productId": self.productId,
            "productName": self.productName,
            "productCategory": self.productCategory,
            "productPrice": self.productPrice,
            "saleAmount": self.saleAmount,
            "saleDiscount": self.saleDiscount,
        }

# %%
sales = []

for i in np.arange(100):
    sales.append(Sale(
        date = "2024-01-01",
        clientName = "John Doe",
        clientType = "Premium",
        productId = "12345",
        productName = "Widget Deluxe",
        productCategory = "Gadgets",
        productPrice = "$199.99",
        saleAmount = "50 units",
        saleDiscount = "10%",

    ))

df_sales = pd.DataFrame([x.to_dict() for x in sales])
df_sales
# Out:
#           date clientName clientType productId    productName productCategory  \
# 0   2024-01-01   John Doe    Premium     12345  Widget Deluxe         Gadgets
# 1   2024-01-01   John Doe    Premium     12345  Widget Deluxe         Gadgets
# 2   2024-01-01   John Doe    Premium     12345  Widget Deluxe         Gadgets
# 3   2024-01-01   John Doe    Premium     12345  Widget Deluxe         Gadgets
# 4   2024-01-01   John Doe    Premium     12345  Widget Deluxe         Gadgets
# ..         ...        ...        ...       ...            ...             ...
# 95  2024-01-01   John Doe    Premium     12345  Widget Deluxe         Gadgets
# 96  2024-01-01   John Doe    Premium     12345  Widget Deluxe         Gadgets
# 97  2024-01-01   John Doe    Premium     12345  Widget Deluxe         Gadgets
# 98  2024-01-01   John Doe    Premium     12345  Widget Deluxe         Gadgets
# 99  2024-01-01   John Doe    Premium     12345  Widget Deluxe         Gadgets
#
#    productPrice saleAmount saleDiscount
# 0       $199.99   50 units          10%
# 1       $199.99   50 units          10%
# 2       $199.99   50 units          10%
# 3       $199.99   50 units          10%
# 4       $199.99   50 units          10%
# ..          ...        ...          ...
# 95      $199.99   50 units          10%
# 96      $199.99   50 units          10%
# 97      $199.99   50 units          10%
# 98      $199.99   50 units          10%
# 99      $199.99   50 units          10%
#
# [100 rows x 9 columns]

# %%
df_sales.to_csv("sales-data-sales.csv")
